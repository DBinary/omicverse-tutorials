# %% [markdown]
# # Differentiation potential with CytoTRACE (dynbenchmark port)
#
# **CytoTRACE** ([Gulati 2020](https://doi.org/10.1126/science.aax0249)) exploits the fact that **less-differentiated cells express more genes**. It scores each cell on its gene-count correlate of stemness, then smooths the score over a kNN graph. The result is a single-axis differentiation potential — useful as a sanity check on directionality even before you pick a topology.
#
# This tutorial uses the **dynbenchmark port** [`pycytotrace-bio`](https://pypi.org/project/pycytotrace-bio/) (R-faithful, 0.1.0). For the CytoTrace 2 implementation packaged inside omicverse, see [`t_cytotrace2.ipynb`](t_cytotrace2.ipynb).
#
# ## Install
#
# ```bash
# pip install omicverse[trajectory]
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

import omicverse as ov
ov.plot_set(font_path='Arial')

# %load_ext autoreload
# %autoreload 2
# Out:
# /scratch/users/steorra/env/omicdev/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# /scratch/users/steorra/env/omicdev/lib/python3.10/site-packages/louvain/__init__.py:54: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound
# 🔬 Starting plot initialization...
# Using already downloaded Arial font from: /tmp/omicverse_arial.ttf
# Registered as: Arial
# 🧬 Detecting GPU devices…
# ✅ NVIDIA CUDA GPUs detected: 1
#     • [CUDA 0] NVIDIA H100 80GB HBM3
#       Memory: 79.1 GB | Compute: 9.0
#
#    ____            _     _    __
#   / __ \____ ___  (_)___| |  / /__  _____________
# ...

# %%
adata = ov.datasets.pancreatic_endocrinogenesis()
# Out:
# ⚠️ File ./data/endocrinogenesis_day15.h5ad already exists
#  Loading data from ./data/endocrinogenesis_day15.h5ad
# ✅ Successfully loaded: 3696 cells × 27998 genes

# %%
adata = ov.pp.preprocess(adata, mode='shiftlog|pearson', n_HVGs=3000)
adata.raw = adata
adata = adata[:, adata.var.highly_variable_features]
ov.pp.scale(adata)
ov.pp.pca(adata, layer='scaled', n_pcs=50)
# Out:
# 🔍 [2026-05-25 02:36:12] Running preprocessing in 'cpu' mode...
# Begin robust gene identification
#     After filtration, 17750/27998 genes are kept.
#     Among 17750 genes, 16426 genes are robust.
# ✅ Robust gene identification completed successfully.
# Begin size normalization: shiftlog and HVGs selection pearson
# 🔍 Count Normalization:
#    Target sum: 500000.0
#    Exclude highly expressed: True
#    Max fraction threshold: 0.2
#    ⚠️ Excluding 1 highly-expressed genes from normalization computation
#    Excluded genes: ['Ghrl']
# ✅ Count Normalization Completed Successfully!
#    ✓ Processed: 3,696 cells × 16,426 genes
#    ✓ Runtime: 0.24s
#
# 🔍 Highly Variable Genes Selection (Experimental):
#    Method: pearson_residuals
#    Target genes: 3,000
#    Theta (overdispersion): 100
# ✅ Experimental HVG Selection Completed Successfully!
#    ✓ Selected: 3,000 highly variable genes out of 16,426 total (18.3%)
#    ✓ Results added to AnnData object:
# ...

# %% [markdown]
# We first inspect the variance explained by principal components to choose a practical PC range for neighbour and graph computations.

# %%
ov.utils.plot_pca_variance_ratio(adata, n_pcs=15)

# %%
ov.pl.umap(
    adata,
    color='clusters'
)
# Out:
# X_umap converted to UMAP to visualize and saved to adata.obsm['UMAP']
# if you want to use X_umap, please set convert=False

# %% [markdown]
# ## CytoTRACE

# %%
Traj=ov.single.TrajInfer(
    adata,
    basis='X_umap',
    groupby='clusters',
    use_rep='scaled|original|X_pca',
    n_comps=50,
)
Traj.set_origin_cells('Ductal')

# %%
Traj.inference(method='cytotrace')

# %% [markdown]
# ## Visualize pseudotime on UMAP

# %%
ov.pl.embedding(
    adata, basis='X_umap',
    color=['clusters', 'cytotrace_stemness', 'cytotrace_pseudotime'],
    frameon='small',
    cmap='RdBu_r',
    ncols=3,
)

# %% [markdown]
# ## Downstream notes
#
# CytoTRACE writes both `cytotrace_stemness` (higher = more stem-like) and `cytotrace_pseudotime = 1 - stemness` (the trajectory-style polarity). Inspect the Ductal cluster — it should sit at the high-stemness, low-pseudotime extreme.

# %% [markdown]
# ## Reference
#
# - Saelens W. et al. *A comparison of single-cell trajectory inference methods.* Nat Biotechnol **37**, 547–554 (2019). [doi:10.1038/s41587-019-0071-9](https://doi.org/10.1038/s41587-019-0071-9)
# - Recommended backend (Slingshot): [t_traj_recommended](../t_traj_recommended.ipynb)
# - All zoo backends: [zoo/index](index.md)
